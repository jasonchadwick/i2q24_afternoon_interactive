# %%
import os
import sys
import copy
import time
import pickle
import numpy as np
from typing import *
import networkx as nx
from multiprocess import Process, Manager

from qiskit import QuantumCircuit
from qiskit.converters import circuit_to_dag

import helper_functions as hf

# %% [markdown]
# # Surface Code Compilation and Resource Estimation #
#
# This notebook will help the users compile a circuit to a quantum processor composed of surface code tiles. Each tile is connected to its nearest four neighbors (a grid topology - the vertices of the grid are the surface code qubits while the edges are the connections between qubits).

# %% [markdown]
# ### Preprocess the circuit ###
#
# For the purpose of this notebook, we assume that we are working with the wide surface code qubit as illusterated in https://quantum-journal.org/papers/q-2018-05-04-62/pdf/. The advantage of working with the wide surface code qubit is that it lets us perform all single qubit Clifford operations classically via a procedure called Edge tracking. This effectively eliminates the time overhead of all single qubit Clifford gates. Thus, we just need to worry about the CNOT gate (a two-qubit Clifford gate), and the T gate (non-Clifford gate).
#
# The following functions take our input circuit and convert them into a CNOT+T circuit. For this, we first decompose all single qubit Non-Clifford gates into Clifford+T using Gridsynth (https://www.mathstat.dal.ca/~selinger/newsynth/, https://arxiv.org/abs/1403.2975). Then, we get rid of all single qubit Clifford operations because of our edge-tracking assumption

# %%
def preprocessing(circuit):
    '''
    The circuit pre-processing steps
    '''

    # convert circuit into cx+u
    while circuit!=circuit.decompose():
        circuit=circuit.decompose()
    
    # convert into CNOT+T
    cliff_plus_T_circuit=hf.rewrite_circuit_in_cliff_plus_T(circuit)

    return cliff_plus_T_circuit

# %%
# change this to a two-step process where we just load a regular circuit and pre-process it ourselves
parent_folder='/Users/sid/Magic State Distillation/ArbitraryMagicStates/chris/scmr_input_circuits/'
input_circuit_name='adder_n28_Cliff+T.qasm'
cliff_T_circuit=QuantumCircuit.from_qasm_file(input_circuit_name)

# %% [markdown]
# ### Initialize The Backend ###
#
# Next, we will initialize the grid to which we would map our circuit. As mentioned before, the backend would be in the shape of a grid where vertices represent qubits and the edges represent connections between those qubits. We also need to define the locations of Magic State factories. These are the sources of Magic States which enable us to do Non-Clifford operations

# %%
def create_adjacency_matrix(V, E):
    '''
    Args:
    V: Number of vertices in the graph
    E: Edges in the graph

    Returns:
    Adjacency matrix of the device topology
    '''
    adj_matrix=[[0 for i in range(V)] for j in range(V)]
    for edge in E:
        adj_matrix[edge[0]][edge[1]]=1
        adj_matrix[edge[1]][edge[0]]=1
    
    return adj_matrix

print('Initializing the backend...')
dimension=100 # 100x100 grid --> 10000 qubits
G=nx.grid_2d_graph(dimension, dimension)
edge_list_temp=list(G.edges())
edge_list_rehashed=[(i[0]*dimension+i[1], j[0]*dimension+j[1]) for i, j in edge_list_temp]
all_ms=[5020, 5040, 5060, 5080] # Locations of the magic state factories. Each location is defined as a unique integer which is equal to dimension*x+y where x and y are the coordinates of the factory in the grid.
backend_graph=create_adjacency_matrix(dimension**2, edge_list_rehashed) # The adjacency matrix of the backend
print('Backend initialized!')
# Out:
# Initializing the backend...
# Backend initialized!

# %% [markdown]
# ### Mapping ###
#
# The process of compilation can be broken into two steps - mapping and routing. During mapping, our aim is to assign logical surface code patches to qubits in the circuit. The mapping algorithm we use is the one given in Movali et. al. https://arxiv.org/pdf/2311.18042

# %% [markdown]
# ##### Get Interaction Graph #####
#
# As described in Molvai et. al., the first step in the mapping algorithm is to get the interaction graph of the circuit. The interaction graph captures the interaction betewen qubits (in the form of CNOTs) and between a qubit and a Magic state factory (in the form of a T gate). The following function can be used to obtain the interaction graph of the circuit

# %%
def get_interaction_graph(circuit:QuantumCircuit):
    '''
    Args:
    circuit: The input quantum circuit

    Gives an interaction graph as given in Molavi et. al. 2023 - Surface Code compilers
    '''
    circuit_dag=circuit_to_dag(circuit)
    
    # This interaction graph has a node 
    # for every qubit and every T gate
    interaction_graph={}
    num_qubits=circuit.num_qubits

    try:
        num_t_gates=circuit.count_ops()['t']
    except:
        num_t_gates=0

    # num t gates count
    num_t_gates_dict={}

    # Add nodes to the interaction graph
    for i in range(num_qubits):
        interaction_graph['q'+str(i)]=[]
        num_t_gates_dict['q'+str(i)]=0
    for i in range(num_t_gates):
        interaction_graph['t'+str(i)]=[]
    
    # Add edges to the interaction graph
    t_count=0 # counter keeping track of t-gates
    for node in circuit_dag.gate_nodes():
        if node.name=='cx':
            arg0='q'+str(node.qargs[0]._index)
            arg1='q'+str(node.qargs[1]._index)
            if arg0 not in interaction_graph[arg1]:
                interaction_graph[arg1].append(arg0)
            if arg1 not in interaction_graph[arg0]:
                interaction_graph[arg0].append(arg1)
        elif node.name=='t':
            interaction_graph['t'+str(t_count)].append('q'+str(node.qargs[0]._index))
            interaction_graph['q'+str(node.qargs[0]._index)].append('t'+str(t_count))
            num_t_gates_dict['q'+str(node.qargs[0]._index)]+=1
            t_count+=1
    
    return interaction_graph, num_t_gates_dict

# %%
list(circuit_to_dag(cliff_T_circuit).gate_nodes())[0].qargs[0]._index
# Out:
# 1

# %%
interaction_graph, num_t_gates_dict=get_interaction_graph(cliff_T_circuit)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 interaction_graph, num_t_gates_dict=get_interaction_graph(cliff_T_circuit)
#
# Cell In[7], line 34, in get_interaction_graph(circuit)
#      32 for node in circuit_dag.gate_nodes():
#      33     if node.name=='cx':
# ---> 34         arg0='q'+str(node.qargs[0].index)
#      35         arg1='q'+str(node.qargs[1].index)
#      36         if arg0 not in interaction_graph[arg1]:
#
# AttributeError: 'Qubit' object has no attribute 'index'

# %% [markdown]
# ##### Get Interaction Chain Set #####
#
# The interaction graph is broken into a set "chains" that can be mapped independently on to the backend. The chains are created in a greedy fashion from the interaction graph.

# %%
def single_t_dfs(interaction_graph:Dict[str, List[str]], vertex:str, visited:Dict[str, bool], path:List[str]):
    '''
    Args:
    interaction_graph: Interaction graph as a dictionary of lists. The index is a 
    vertex of the graph. The list contains the neighbors of the vertex (Adjacency list)
    vertex: The vertex at which we are currently at (during the dfs)
    visited: A dictionary keeping track of visited nodes in the interaction graph
    path: The current path that we are building during the dfs

    Returns:
    path: Updates the path and returns it
    
    '''

    def is_complete(path):
        '''Gives conditions for path to be complete -- i.e. we do
        not need to add any more vertices to it'''
        if len(path)>1 and path[-1][0]=='t':
            return True
        else:
            return False
    
    # if path is a complete path
    # just return it
    if is_complete(path):
        return path
    
    # assert that the path is one out of the two possible incomplete paths
    for el in path[1:]:
        assert el[0]=='q'
    
    # figure out whether a T gate is present in the path
    is_t_present=False
    for el in path:
        if el[0]=='t':
            is_t_present=True
            break
    
    if is_t_present and vertex[0]=='t':
        return path
    
    visited[vertex]=True
    path.append(vertex)

    # path is not complete yet -- keep going
    neighbors=interaction_graph[vertex]
    if vertex[0]=='q':
        for neighbor in neighbors:
            if not visited[neighbor]:
                path=single_t_dfs(interaction_graph, neighbor, visited, path)
            else:
                continue
    else:
        for neighbor in neighbors:
            if not visited[neighbor] and neighbor[0]=='q':
                path=single_t_dfs(interaction_graph, neighbor, visited, path)
            else:
                continue
    
    return path

def get_interaction_chain_set(interaction_graph:Dict[str, List[str]]):
    '''
    Args:
    interaction_graph: Interaction graph as a dictionary of lists. The index is a 
    vertex of the graph. The list contains the neighbors of the vertex (Adjacency list)

    Returns a set of interaction chains. It is a set of maximal paths such that 
    each vertex in the graph is in exactly one path. Further, each path must 
    contain at most one T gate
    '''
    # dictionary to keep track of visited nodes
    visited={node:False for node in interaction_graph.keys()}
    maximal_paths=[]
    all_keys=list(interaction_graph.keys())

    # dfs to find maximal paths
    while sum(visited.values())<len(visited.keys()):
        for vertex in all_keys:
            if not visited[vertex]:
                path=[]
                path=single_t_dfs(interaction_graph, vertex, visited, path) # dfs with the constraint that each path must contain at most one T gate -- that too either at the start or the end
                maximal_paths.append(path)
    
    return maximal_paths, visited

# %%
interaction_chain_set, visited=get_interaction_chain_set(interaction_graph)
assert sum(visited.values())==len(visited.keys()) # we need to visit all nodes in the interaction graph

# %% [markdown]
# ##### Map the Independent Interaction Chains #####

# %%
def update_available_locations(available_locations:List[int], interaction_graph:Dict[str, List[str]], mapping:Dict[str, int], available_ms_factories_to_qubits:Dict[int, int]):
    '''
    Args:
    available_locations: List of available locations on the graph
    interaction_graph: Interaction graph of the circuit
    mapping: Mapping from virtual qubits to physical qubit locations in the graph in the form of a dictionary.
    available_ms_factories_to_qubits: Dictionary keeping track of the closest magic state factory to each mapped qubit
    '''
    updated_locations=[i for i in available_locations]
    invalid_nodes=all_ms+list(mapping.values())

    virtual_qubits=list(mapping.keys())
    
    if len(mapping.keys())>=2:
        for i in range(len(virtual_qubits)-1):
            for j in range(i, len(virtual_qubits)):

                physical_qbi=mapping[virtual_qubits[i]]
                physical_qbj=mapping[virtual_qubits[j]]

                # if these two qubits are connected in the circuit
                if virtual_qubits[i] in interaction_graph[virtual_qubits[j]]:
                    assert virtual_qubits[j] in interaction_graph[virtual_qubits[i]] # sanity check
                    shortest_path=hf.bfs_shortest_path(backend_graph, physical_qbi, physical_qbj, invalid_nodes=invalid_nodes)
                    assert shortest_path[0]==physical_qbi and shortest_path[-1]==physical_qbj # sanity check
                    for el_idx, el in enumerate(shortest_path):
                        
                        # make sure already mapped locations are not in available locations
                        if el_idx==0 or el_idx==len(shortest_path)-1:
                            assert el not in updated_locations
                        
                        if el in updated_locations:
                            updated_locations.remove(el)
                        
                    for el in shortest_path:
                        assert el not in updated_locations

    # make sure each of these mapped qubits have a way to reach at least one magic state factory        
    for i in range(len(virtual_qubits)):
        neighbors=interaction_graph[virtual_qubits[i]]
        flag=False
        for el in neighbors:
            if el[0]=='t':
                flag=True
                break

        if flag: # if this qubit interacts with a T gate
            shortest_length=np.inf
            shortest_route=None
            
            for ms_loc in all_ms:
                route=hf.bfs_shortest_path(backend_graph, ms_loc, mapping[virtual_qubits[i]], invalid_nodes=invalid_nodes)
                if route[-1]==mapping[virtual_qubits[i]] and route[0]==ms_loc: # valid route
                    
                    if len(route)<shortest_length:
                        shortest_length=len(route)
                        shortest_route=route
                        available_ms_factories_to_qubits[mapping[virtual_qubits[i]]]=ms_loc # record the closest magic state factory to mapped qubit
            
            assert shortest_route is not None # sanity check -- should have found at least one route

            for el in shortest_route[1:-1]:
                if el in updated_locations:
                    updated_locations.remove(el)

    return updated_locations, available_ms_factories_to_qubits

def map_chain(available_locations:List[int], interaction_chain:List[str], interaction_graph:Dict[str, List[str]], available_ms_factories_to_qubits:Dict[int, int]):
    '''
    Args:
    available_locations: List of available locations on the graph
    interaction_chain_set: Set of interaction chains
    interaction_graph: Interaction_graph of the circuit
    available_ms_factories_to_qubits: Dictionary keeping track of the closest magic state factory to each mapped qubit 
    '''
    graph=backend_graph
    ms=all_ms
    dimension=int(len(graph)**0.5)

    # dictionary to keep track of the mapping
    chain_mapping={}

    # make sure that 't' is always the last element in the chain
    if interaction_chain[0][0]=='t':
        interaction_chain.reverse()

    # base case when chain has just one element and its a T gate    
    if len(interaction_chain)==1 and interaction_chain[0][0]=='t':
        return chain_mapping, available_locations, available_ms_factories_to_qubits  
    # base case when the chain has just one element and its a qubit
    elif len(interaction_chain)==1 and interaction_chain[0][0]=='q':
        chain_mapping[interaction_chain[0]]=available_locations.pop()
        available_locations, available_ms_factories_to_qubits=update_available_locations(available_locations, interaction_graph, chain_mapping, available_ms_factories_to_qubits)
        return chain_mapping, available_locations, available_ms_factories_to_qubits
    else:
        head, p_dash = interaction_chain[0], interaction_chain[1:]
        new_chain_mapping, available_locations, available_ms_factories_to_qubits=map_chain(available_locations, p_dash, interaction_graph, available_ms_factories_to_qubits)
        chain_mapping.update(new_chain_mapping)

        # subset of available locations which are at 
        # distance 2 from the qubit mapping of p_dash[0]
        neighbors=[]
        
        # get all locations at distance two -- neighbors
        if len(p_dash)==1 and p_dash[0][0]=='t':
            for ms_loc in ms:
                co_ordinates=(ms_loc//dimension, ms_loc%dimension)
                potential_neighbors=[(co_ordinates[0]+i, co_ordinates[1]+j) for i in [-2, -1, 0, 1, 2] for j in [-2, -1, 0, 1, 2] if abs(i)+abs(j)==2]
                valid_neighbors=[i*dimension+j for i, j in potential_neighbors if i>=0 and i<dimension and j>=0 and j<dimension and i*dimension+j in available_locations]
                neighbors+=valid_neighbors
        else:
            head_p_dash_mapped=chain_mapping[p_dash[0]]
            co_ordinates=(head_p_dash_mapped//dimension, head_p_dash_mapped%dimension)
            potential_neighbors=[(co_ordinates[0]+i, co_ordinates[1]+j) for i in [-2, -1, 0, 1, 2] for j in [-2, -1, 0, 1, 2] if abs(i)+abs(j)==2]
            valid_neighbors=[i*dimension+j for i, j in potential_neighbors if i>=0 and i<dimension and j>=0 and j<dimension and i*dimension+j in available_locations]
            neighbors+=valid_neighbors
        
        if len(neighbors)!= 0:
            chain_mapping[head]=neighbors.pop()
            available_locations.remove(chain_mapping[head])
            available_locations, available_ms_factories_to_qubits=update_available_locations(available_locations, interaction_graph, chain_mapping, available_ms_factories_to_qubits)
        else:
            chain_mapping[head]=available_locations.pop()
            available_locations, available_ms_factories_to_qubits=update_available_locations(available_locations, interaction_graph, chain_mapping, available_ms_factories_to_qubits)
        
        return chain_mapping, available_locations, available_ms_factories_to_qubits

def structural_mapping_algorithm(circuit:QuantumCircuit):
    '''
    Args:
    circuit: The circuit that we want to map
    '''
    graph=backend_graph # the graph of the device connectivity
    ms=all_ms # magic state locations
    dimension=int(len(graph)**0.5) # dimension of the grid

    # get the interaction chain set
    interaction_graph, num_t_gates_dict=get_interaction_graph(circuit)
    interaction_chain_set, visited=get_interaction_chain_set(interaction_graph)

    # store available_locations in reverse order of
    # distance from the magic state factories -- the ones close to 
    # any magic state factory is preferred
    available_locations={}
    for i in range(len(graph)):
        if i in ms:
            continue
        else:
            co_ord=(i//dimension, i%dimension)
            dists=[abs(co_ord[0]-ms_loc//dimension)+abs(co_ord[1]-ms_loc%dimension) for ms_loc in ms]
            max_dist=max(dists)
            available_locations[i]=max_dist
    
    # sort the available locations according to value
    available_locations=sorted(available_locations, key=lambda x: available_locations[x], reverse=True)

    # run the map-chain algorithm
    final_mapping={}
    available_ms_factories_to_qubits={} # keeps track of the closest magic state factory to each mapped qubit
    for chain_idx, chain in enumerate(interaction_chain_set):
        mapping, available_locations, available_ms_factories_to_qubits=map_chain(available_locations, chain, interaction_graph, available_ms_factories_to_qubits)
        final_mapping.update(mapping)

    # refine final_mapping
    final_mapping_refined={int(key[1:]):val for key, val in final_mapping.items()}
    del final_mapping

    return final_mapping_refined, available_ms_factories_to_qubits

# %%
mapping, available_ms_factories_to_qubits=structural_mapping_algorithm(cliff_T_circuit)
# Out:
# /var/folders/w9/82hl73yj3_5937ld729s8j980000gp/T/ipykernel_18000/3162911751.py:34: DeprecationWarning: The property ``qiskit.circuit.bit.Bit.index`` is deprecated as of qiskit-terra 0.17. It will be removed no earlier than 3 months after the release date. Instead, use :meth:`~qiskit.circuit.quantumcircuit.QuantumCircuit.find_bit` to find all the containing registers within a circuit and the index of the bit within the circuit.
#   arg0='q'+str(node.qargs[0].index)
# /var/folders/w9/82hl73yj3_5937ld729s8j980000gp/T/ipykernel_18000/3162911751.py:35: DeprecationWarning: The property ``qiskit.circuit.bit.Bit.index`` is deprecated as of qiskit-terra 0.17. It will be removed no earlier than 3 months after the release date. Instead, use :meth:`~qiskit.circuit.quantumcircuit.QuantumCircuit.find_bit` to find all the containing registers within a circuit and the index of the bit within the circuit.
#   arg1='q'+str(node.qargs[1].index)
# /var/folders/w9/82hl73yj3_5937ld729s8j980000gp/T/ipykernel_18000/3162911751.py:41: DeprecationWarning: The property ``qiskit.circuit.bit.Bit.index`` is deprecated as of qiskit-terra 0.17. It will be removed no earlier than 3 months after the release date. Instead, use :meth:`~qiskit.circuit.quantumcircuit.QuantumCircuit.find_bit` to find all the containing registers within a circuit and the index of the bit within the circuit.
#   interaction_graph['t'+str(t_count)].append('q'+str(node.qargs[0].index))
# /var/folders/w9/82hl73yj3_5937ld729s8j980000gp/T/ipykernel_18000/3162911751.py:42: DeprecationWarning: The property ``qiskit.circuit.bit.Bit.index`` is deprecated as of qiskit-terra 0.17. It will be removed no earlier than 3 months after the release date. Instead, use :meth:`~qiskit.circuit.quantumcircuit.QuantumCircuit.find_bit` to find all the containing registers within a circuit and the index of the bit within the circuit.
#   interaction_graph['q'+str(node.qargs[0].index)].append('t'+str(t_count))
# /var/folders/w9/82hl73yj3_5937ld729s8j980000gp/T/ipykernel_18000/3162911751.py:43: DeprecationWarning: The property ``qiskit.circuit.bit.Bit.index`` is deprecated as of qiskit-terra 0.17. It will be removed no earlier than 3 months after the release date. Instead, use :meth:`~qiskit.circuit.quantumcircuit.QuantumCircuit.find_bit` to find all the containing registers within a circuit and the index of the bit within the circuit.
#   num_t_gates_dict['q'+str(node.qargs[0].index)]+=1

# %% [markdown]
# ### Routing ###
#
# We have obtained the mapping now. We know the co-ordinates of the logical qubit patches that the circuit qubits would be mapped to. The next step is to determine how the CNOTs and T gates would be executed. Both CNOTs and T gate execution require lattice surgery which involves initializing an ancilla patch between the control and target qubits. For any two ancilla patches, their ancilla patches cannot intersect (i.e. there cannot be a qubit which is common to multiple ancilla patches in the same time step). We also want to minimize the length of these ancilla patches so that the chances of crossover between two ancilla patches is minimized. Hence the problem of routing essentially translates to that of finding the set of shortest non-intersecting ancilla patches for all operations occuring in the same time step.
#
# If for any given operation, we cannot find an ancilla patch that doesn't intersect with all other ancilla patches in the same time step, we perform the operation in the next time step.

# %%
def clean_up_routing_output(routing_output):
    '''The routing output is stored in a really bad format -- clean that up'''
    
    sorted_output=sorted(routing_output, key=lambda x: x[0])
    
    # get the length of the routing list
    length=0
    for el in sorted_output:
        if len(el[1])>0:
            length+=len(el[1])

    clean_output={idx:None for idx in range(length)}

    counter=0
    for el_idx, el in enumerate(sorted_output):
        ll=el[1]
        if len(ll)>0:
            for element in ll:
                gate_routes={}
                for key, val in element.items():
                    assert key not in gate_routes
                    gate_routes[key]=val
                clean_output[counter]=gate_routes
                counter+=1

    assert counter==length      
    return clean_output

def shortest_find_ndp_algorithm(graph, pairs:Dict[int, Dict[str, Union[str, List[int]]]], mapping:Dict[int, int]):
    '''
    Args:
    pairs: Vertex pairs as a dictionary of dictionaries. Each dictionary contains  
    the vertices associated with the gate, and the name of the gate. The pairs dict is 
    queried using a unique_id.

    graph: Graph as an adjacency matrix of dimension VxV - numpy array
    pairs: Dictionary of pairs of vertices to be routed
    mapping: Mapping from virtual qubits to physical qubit locations in the graph in the form of a dictionary.

    Returns:
    All possible routes for that particular step
    '''
    relevant_pairs=copy.deepcopy(pairs)
    step={}
    
    while len(list(relevant_pairs.keys()))>0:

        # index corresponding to the closest vertices
        shortest_pidx=np.inf
        shortest_path=None
        shortest_length=np.inf
        shortest_unique_id=None

        # append the shortest path in step
        is_at_least_one_path=False 
        for unique_id, gate in relevant_pairs.items():
            
            # BFS does terminate, it finds something everytime
            assert (gate['indices'][0] != gate['indices'][1])
            path=hf.bfs_shortest_path(graph, gate['indices'][0], gate['indices'][1], all_ms+list(mapping.values()))

            try:
                assert path[0]==gate['indices'][0] and path[-1]==gate['indices'][1]
            except:
                continue
            
            # make sure that the bfs path is a valid path
            if path[0]==gate['indices'][0] and path[-1]==gate['indices'][1]:
                is_at_least_one_path=True

            if len(path)<shortest_length:
                shortest_path=path
                shortest_length=len(path)
                shortest_unique_id=unique_id
        
        # if no valid paths found, break the loop
        if not is_at_least_one_path:
            break
        
        step[shortest_unique_id]=shortest_path
        del relevant_pairs[shortest_unique_id]

        # remove all vertices in path from the graph
        for i in range(len(shortest_path)):
            graph[shortest_path[i], :]=0
            graph[:, shortest_path[i]]=0
    
    return step

def greedy_routing_algorithm(layer_infos, mapping:Dict[int, int], available_ms_factories_to_qubits:Dict[int, int], queue):
    '''
    Args:
    layer_infos: A list of dicts({'layer_idx':int, 'layer':DAGCircuitLayer}) containing information about the layers in the circuit
    mapping: Mapping from virtual qubits to physical qubit locations in the graph in the form of a dictionary.
    Assumes that keys are the virtual qubit indices and the values are the physical qubit indices.
    queue: Multiprocessing queue to store the results of the routing algorithm
    available_ms_factories_to_qubits: Dictionary keeping track of the closest magic state factory to each mapped qubit
    '''
    graph=np.array(backend_graph)
    ms=all_ms

    for layer_info in layer_infos:
        steps=[]
        layer_idx=layer_info['layer_idx']
        print('Current layer index is: ', layer_idx)
        layer=layer_info['layer']
        layer_graph=layer['graph']
        gate_nodes=layer_graph.gate_nodes()

        # get the set of all unrouted nodes
        unrouted={}
        unique_id=0 # Assign each gate in the layer with a unique id
        for gate_idx, gate in enumerate(gate_nodes):

            # The case of CNOT gates
            if len(gate.qargs)==2 and gate.name=='cx':
                post_mapping_indices=[mapping[gate.qargs[0].index], mapping[gate.qargs[1].index]]
                gate_relevant_vals={'name':gate.name, 'indices':post_mapping_indices}
                unrouted[unique_id]=gate_relevant_vals
            
            elif gate.name=='t' and len(gate.qargs)==1:
                
                # route from the closest magic state factory
                post_mapping_indices=[available_ms_factories_to_qubits[mapping[gate.qargs[0].index]], mapping[gate.qargs[0].index]] # defaulting to choosing the first magic state factory right now
                gate_relevant_vals={'name':gate.name, 'indices':post_mapping_indices}
                unrouted[unique_id]=gate_relevant_vals
            
            unique_id+=1
        
        # greedily route the gates
        t0=time.time()
        while len(list(unrouted.keys()))>0:

            graph_copy=graph.copy()
            next=shortest_find_ndp_algorithm(graph_copy, unrouted, mapping)
            
            steps.append(next)
            
            new_unrouted={}
            for el_idx, el_val in unrouted.items():
                if el_idx not in next:
                    new_unrouted[el_idx]=el_val
            
            unrouted=new_unrouted
        t1=time.time()
        queue.put([layer_idx, steps])
        print('Layer idx:', layer_idx, 'routing completed in time:', t1-t0, 'seconds!\n')

def parallel_greedy_routing_algorithm(circuit:QuantumCircuit, mapping:Dict[int, int], available_ms_factories_to_qubits:Dict[int, int]):
    '''
    Args:
    circuit: Quantum circuit to be routed as a DAG
    mapping: Mapping from virtual qubits to physical qubit locations in the graph in the form of a dictionary.
    Assumes that keys are the virtual qubit indices and the values are the physical qubit indices.
    available_ms_factories_to_qubits: Dictionary keeping track of the closest magic state factory to each mapped qubit
    '''
    def get_layers(circuit:QuantumCircuit):
        
        dag_circuit=circuit_to_dag(circuit)
        layers=list(dag_circuit.layers())
        return layers

    mapping_vals=list(mapping.values())
    available_qubit_locs_keys=list(available_ms_factories_to_qubits.keys())
    # for idx in mapping_vals:
    #     assert idx in available_qubit_locs_keys
    for idx in available_qubit_locs_keys:
        assert idx in mapping_vals
    # assert len(available_qubit_locs_keys)==len(mapping_vals)

    graph=np.array(backend_graph)
    ms=all_ms

    steps=[]
    layers=get_layers(circuit)
    layer_infos=[{'layer_idx':layer_idx, 'layer':layer} for layer_idx, layer in enumerate(layers)]

    print('Number of layers:', len(layers))

    def process_layer(layer_infos, result_queue):
        return greedy_routing_algorithm(layer_infos, mapping, available_ms_factories_to_qubits, result_queue)
    
    # fire all parallel processes
    result_queue=Manager().Queue()
    n_proc=os.cpu_count()-1
    len_each_proc=len(layer_infos)//n_proc
    processes=[]
    results=[]

    print('Launching processes!')
    for i in range(n_proc):
        print('Launched process number ', i, '!')
        process=Process(target=process_layer, args=(layer_infos[i*len_each_proc:(i+1)*len_each_proc], result_queue))
        processes.append(process)
        process.start()
    
    # wait for all processes to finish
    # and collect the results
    for process in processes:
        process.join()
    
    while not result_queue.empty():
        results.append(result_queue.get())
    
    results=clean_up_routing_output(results)
    return results

# %%
steps=parallel_greedy_routing_algorithm(cliff_T_circuit, mapping, available_ms_factories_to_qubits)
# Out:
# Number of layers: 306
# Launching processes!
# Launched process number  0 !
# Launched process number  1 !
# Launched process number  2 !
# Launched process number  3 !
# Launched process number  4 !
# Launched process number  5 !
# Launched process number  6 !
# Current layer index is:  258Current layer index is:
#  129Current layer index is:
# Layer idx:
# /var/folders/w9/82hl73yj3_5937ld729s8j980000gp/T/ipykernel_18000/548014944.py:124: DeprecationWarning: The property ``qiskit.circuit.bit.Bit.index`` is deprecated as of qiskit-terra 0.17. It will be removed no earlier than 3 months after the release date. Instead, use :meth:`~qiskit.circuit.quantumcircuit.QuantumCircuit.find_bit` to find all the containing registers within a circuit and the index of the bit within the circuit.
#   post_mapping_indices=[available_ms_factories_to_qubits[mapping[gate.qargs[0].index]], mapping[gate.qargs[0].index]] # defaulting to choosing the first magic state factory right now
# 258
# /var/folders/w9/82hl73yj3_5937ld729s8j980000gp/T/ipykernel_18000/548014944.py:117: DeprecationWarning: The property ``qiskit.circuit.bit.Bit.index`` is deprecated as of qiskit-terra 0.17. It will be removed no earlier than 3 months after the release date. Instead, use :meth:`~qiskit.circuit.quantumcircuit.QuantumCircuit.find_bit` to find all the containing registers within a circuit and the index of the bit within the circuit.
#   post_mapping_indices=[mapping[gate.qargs[0].index], mapping[gate.qargs[1].index]]
# 0
#  Current layer index is: routing completed in time:  Layer idx:2158.821487426757812e-06
# /var/folders/w9/82hl73yj3_5937ld729s8j980000gp/T/ipykernel_18000/548014944.py:124: DeprecationWarning: The property ``qiskit.circuit.bit.Bit.index`` is deprecated as of qiskit-terra 0.17. It will be removed no earlier than 3 months after the release date. Instead, use :meth:`~qiskit.circuit.quantumcircuit.QuantumCircuit.find_bit` to find all the containing registers within a circuit and the index of the bit within the circuit.
#   post_mapping_indices=[available_ms_factories_to_qubits[mapping[gate.qargs[0].index]], mapping[gate.qargs[0].index]] # defaulting to choosing the first magic state factory right now
# 0seconds!
#
# Current layer index is: routing completed in time:Current layer index is:  Current layer index is:  4.0531158447265625e-06 Current layer index is:  259172
# 86 seconds!
# /var/folders/w9/82hl73yj3_5937ld729s8j980000gp/T/ipykernel_18000/548014944.py:124: DeprecationWarning: The property ``qiskit.circuit.bit.Bit.index`` is deprecated as of qiskit-terra 0.17. It will be removed no earlier than 3 months after the release date. Instead, use :meth:`~qiskit.circuit.quantumcircuit.QuantumCircuit.find_bit` to find all the containing registers within a circuit and the index of the bit within the circuit.
#   post_mapping_indices=[available_ms_factories_to_qubits[mapping[gate.qargs[0].index]], mapping[gate.qargs[0].index]] # defaulting to choosing the first magic state factory right now
# 43
# /var/folders/w9/82hl73yj3_5937ld729s8j980000gp/T/ipykernel_18000/548014944.py:117: DeprecationWarning: The property ``qiskit.circuit.bit.Bit.index`` is deprecated as of qiskit-terra 0.17. It will be removed no earlier than 3 months after the release date. Instead, use :meth:`~qiskit.circuit.quantumcircuit.QuantumCircuit.find_bit` to find all the containing registers within a circuit and the index of the bit within the circuit.
#   post_mapping_indices=[mapping[gate.qargs[0].index], mapping[gate.qargs[1].index]]
# /var/folders/w9/82hl73yj3_5937ld729s8j980000gp/T/ipykernel_18000/548014944.py:124: DeprecationWarning: The property ``qiskit.circuit.bit.Bit.index`` is deprecated as of qiskit-terra 0.17. It will be removed no earlier than 3 months after the release date. Instead, use :meth:`~qiskit.circuit.quantumcircuit.QuantumCircuit.find_bit` to find all the containing registers within a circuit and the index of the bit within the circuit.
#   post_mapping_indices=[available_ms_factories_to_qubits[mapping[gate.qargs[0].index]], mapping[gate.qargs[0].index]] # defaulting to choosing the first magic state factory right now
# Current layer index is:  Layer idx:1
# /var/folders/w9/82hl73yj3_5937ld729s8j980000gp/T/ipykernel_18000/548014944.py:117: DeprecationWarning: The property ``qiskit.circuit.bit.Bit.index`` is deprecated as of qiskit-terra 0.17. It will be removed no earlier than 3 months after the release date. Instead, use :meth:`~qiskit.circuit.quantumcircuit.QuantumCircuit.find_bit` to find all the containing registers within a circuit and the index of the bit within the circuit.
#   post_mapping_indices=[mapping[gate.qargs[0].index], mapping[gate.qargs[1].index]]
# 43 routing completed in time: 2.86102294921875e-06 seconds!
#
# Current layer index is:  44
# Layer idx: 44 routing completed in time: 3.814697265625e-06 seconds!
#
# Current layer index is:  45
# /var/folders/w9/82hl73yj3_5937ld729s8j980000gp/T/ipykernel_18000/548014944.py:124: DeprecationWarning: The property ``qiskit.circuit.bit.Bit.index`` is deprecated as of qiskit-terra 0.17. It will be removed no earlier than 3 months after the release date. Instead, use :meth:`~qiskit.circuit.quantumcircuit.QuantumCircuit.find_bit` to find all the containing registers within a circuit and the index of the bit within the circuit.
#   post_mapping_indices=[available_ms_factories_to_qubits[mapping[gate.qargs[0].index]], mapping[gate.qargs[0].index]] # defaulting to choosing the first magic state factory right now
# Layer idx:Layer idx:  Layer idx:17286   259routing completed in time: routing completed in time: routing completed in time: 2.4118590354919434 2.4059090614318848 2.4370248317718506 seconds!
#  seconds!
#
# seconds!
#
# Current layer index is:
#  Current layer index is:  87Current layer index is:
# 173
# 260
# /var/folders/w9/82hl73yj3_5937ld729s8j980000gp/T/ipykernel_18000/548014944.py:124: DeprecationWarning: The property ``qiskit.circuit.bit.Bit.index`` is deprecated as of qiskit-terra 0.17. It will be removed no earlier than 3 months after the release date. Instead, use :meth:`~qiskit.circuit.quantumcircuit.QuantumCircuit.find_bit` to find all the containing registers within a circuit and the index of the bit within the circuit.
#   post_mapping_indices=[available_ms_factories_to_qubits[mapping[gate.qargs[0].index]], mapping[gate.qargs[0].index]] # defaulting to choosing the first magic state factory right now
# /var/folders/w9/82hl73yj3_5937ld729s8j980000gp/T/ipykernel_18000/548014944.py:117: DeprecationWarning: The property ``qiskit.circuit.bit.Bit.index`` is deprecated as of qiskit-terra 0.17. It will be removed no earlier than 3 months after the release date. Instead, use :meth:`~qiskit.circuit.quantumcircuit.QuantumCircuit.find_bit` to find all the containing registers within a circuit and the index of the bit within the circuit.
#   post_mapping_indices=[mapping[gate.qargs[0].index], mapping[gate.qargs[1].index]]
# Layer idx: 45 routing completed in time: 2.7369511127471924 seconds!
#
# Current layer index is:  46
# /var/folders/w9/82hl73yj3_5937ld729s8j980000gp/T/ipykernel_18000/548014944.py:117: DeprecationWarning: The property ``qiskit.circuit.bit.Bit.index`` is deprecated as of qiskit-terra 0.17. It will be removed no earlier than 3 months after the release date. Instead, use :meth:`~qiskit.circuit.quantumcircuit.QuantumCircuit.find_bit` to find all the containing registers within a circuit and the index of the bit within the circuit.
#   post_mapping_indices=[mapping[gate.qargs[0].index], mapping[gate.qargs[1].index]]
# Layer idx: 215 routing completed in time: 3.446913957595825 seconds!
#
# Current layer index is:  216
# /var/folders/w9/82hl73yj3_5937ld729s8j980000gp/T/ipykernel_18000/548014944.py:117: DeprecationWarning: The property ``qiskit.circuit.bit.Bit.index`` is deprecated as of qiskit-terra 0.17. It will be removed no earlier than 3 months after the release date. Instead, use :meth:`~qiskit.circuit.quantumcircuit.QuantumCircuit.find_bit` to find all the containing registers within a circuit and the index of the bit within the circuit.
#   post_mapping_indices=[mapping[gate.qargs[0].index], mapping[gate.qargs[1].index]]
# Layer idx: 1 routing completed in time: 3.5988757610321045 seconds!
#
# Current layer index is:  2
# Layer idx: 87 routing completed in time: 1.737562656402588 seconds!
#
# Current layer index is:  88
# /var/folders/w9/82hl73yj3_5937ld729s8j980000gp/T/ipykernel_18000/548014944.py:117: DeprecationWarning: The property ``qiskit.circuit.bit.Bit.index`` is deprecated as of qiskit-terra 0.17. It will be removed no earlier than 3 months after the release date. Instead, use :meth:`~qiskit.circuit.quantumcircuit.QuantumCircuit.find_bit` to find all the containing registers within a circuit and the index of the bit within the circuit.
#   post_mapping_indices=[mapping[gate.qargs[0].index], mapping[gate.qargs[1].index]]
# Layer idx: 173 routing completed in time: 2.3288838863372803 seconds!
#
# Current layer index is:  174
# Layer idx: 46 routing completed in time: 1.8996152877807617 seconds!
#
# Current layer index is:  47
# Layer idx: 260 routing completed in time: 2.5933001041412354 seconds!
#
# Current layer index is:  261
# Layer idx: 216 routing completed in time: 2.8648109436035156 seconds!
#
# Current layer index is: Layer idx:  217
# 174 routing completed in time: 1.5299923419952393 seconds!
#
# Current layer index is:  175
# Layer idx: 47 routing completed in time: 1.5228328704833984 seconds!
#
# Current layer index is:  48
# Layer idx: 261 routing completed in time: 1.9593451023101807 seconds!
#
# Current layer index is: Layer idx:  26248
#  routing completed in time: 0.49036693572998047 seconds!
#
# Current layer index is:  49
# Layer idx: 49 routing completed in time: 0.5663719177246094 seconds!
#
# Current layer index is:  50
# Layer idx: 50 routing completed in time: 5.0067901611328125e-06 seconds!
#
# Current layer index is:  51
# Layer idx: 88 routing completed in time: 3.8187978267669678 seconds!
#
# Current layer index is:  89
# Layer idx: 262 routing completed in time: 1.099625825881958 seconds!
#
# Current layer index is:  263
# Layer idx: 263 routing completed in time: 5.0067901611328125e-06 seconds!
#
# Current layer index is:  264
# Layer idx: 264 routing completed in time: 4.0531158447265625e-06 seconds!
#
# Current layer index is:  265
# Layer idx: 265 routing completed in time: 3.0994415283203125e-06 seconds!
#
# Current layer index is:  266
# Layer idx: 51 routing completed in time: 0.8133690357208252 seconds!
#
# Current layer index is:  52
# Layer idx: 175 routing completed in time: 2.459970235824585 seconds!
#
# Current layer index is:  176
# Layer idx: 52 routing completed in time: 0.9949600696563721 seconds!
#
# Current layer index is:  53Layer idx:
#  266 routing completed in time: 1.2382230758666992 seconds!
#
# Current layer index is:  267
# Layer idx: 267 routing completed in time: 3.0994415283203125e-06 seconds!
#
# Current layer index is:  268
# Layer idx: 268 routing completed in time: 3.0994415283203125e-06 seconds!
#
# Current layer index is:  269
# Layer idx: 2 routing completed in time: 6.392131805419922 seconds!
#
# Current layer index is:  3
# Layer idx: 3 routing completed in time: 3.0994415283203125e-06 seconds!
#
# Current layer index is:  4
# Layer idx: 4 routing completed in time: 6.198883056640625e-06 seconds!
#
# Current layer index is:  5
# Layer idx: 5 routing completed in time: 5.9604644775390625e-06 seconds!
#
# Current layer index is:  6
# Layer idx: 176 routing completed in time: 2.04321026802063 seconds!
#
# Current layer index is:  177
# Layer idx: 269 routing completed in time: 1.0816969871520996 seconds!
#
# Current layer index is:  270
# Layer idx: 6 routing completed in time: 1.0649549961090088 seconds!
#
# Current layer index is:  7
# Layer idx: 7 routing completed in time: 3.814697265625e-06 seconds!
#
# Current layer index is:  8
# Layer idx: 8 routing completed in time: 8.106231689453125e-06 seconds!
#
# Current layer index is:  9
# /var/folders/w9/82hl73yj3_5937ld729s8j980000gp/T/ipykernel_18000/548014944.py:124: DeprecationWarning: The property ``qiskit.circuit.bit.Bit.index`` is deprecated as of qiskit-terra 0.17. It will be removed no earlier than 3 months after the release date. Instead, use :meth:`~qiskit.circuit.quantumcircuit.QuantumCircuit.find_bit` to find all the containing registers within a circuit and the index of the bit within the circuit.
#   post_mapping_indices=[available_ms_factories_to_qubits[mapping[gate.qargs[0].index]], mapping[gate.qargs[0].index]] # defaulting to choosing the first magic state factory right now
# Layer idx: 270 routing completed in time: 0.7045578956604004 seconds!
#
# Current layer index is:  271
# Layer idx: 9 routing completed in time: 0.397611141204834 seconds!
#
# Current layer index is:  10
# Layer idx: 217 routing completed in time: 5.876224040985107 seconds!
#
# Current layer index is:  218
# Layer idx: 271 routing completed in time: 0.7818670272827148 seconds!
#
# Current layer index is:  272
# Layer idx: 177 routing completed in time: 1.9535999298095703 seconds!
#
# Current layer index is:  178
# Layer idx: 272 routing completed in time: 0.4819049835205078 seconds!
#
# Current layer index is:  273
# Layer idx: 273 routing completed in time: 0.32487988471984863 seconds!
#
# Current layer index is:  274
# Layer idx: 274 routing completed in time: 4.0531158447265625e-06 seconds!
#
# Current layer index is:  275
# Layer idx: 178 routing completed in time: 0.8477528095245361 seconds!
#
# Current layer index is:  179
# Layer idx: 275 routing completed in time: 0.8484318256378174 seconds!
#
# Current layer index is:  276
# Layer idx: 179 routing completed in time: 1.0135817527770996 seconds!
#
# Current layer index is:  180
# Layer idx:Layer idx: 129 276  routing completed in time:routing completed in time:  0.3871381282806396515.33761477470398  seconds!
# seconds!
#
#
# Current layer index is:  Current layer index is: 277
# 130
# Layer idx: 130 routing completed in time: 0.5401759147644043 Layer idx:seconds!
#
# 180Current layer index is:   routing completed in time:131 0.7815122604370117
#  seconds!
#
# Current layer index is:  181
# Layer idx: 131 routing completed in time: 0.7371909618377686 seconds!
#
# Current layer index is:  132
# Layer idx: 132 routing completed in time: 0.3539397716522217 seconds!
#
# Current layer index is:  133
# Layer idx: 10 routing completed in time: 5.266063928604126 seconds!
#
# Layer idx:Current layer index is:   11133
# routing completed in time: 0.3401908874511719 seconds!
#
# Current layer index is:  134
# Layer idx: 134 routing completed in time: 0.35988688468933105 seconds!
#
# Current layer index is:  135
# Layer idx: 11 routing completed in time: 0.9900879859924316 Layer idx:seconds!
#  135
#  Current layer index is: routing completed in time:  120.4817028045654297
#  seconds!
#
# Current layer index is:  136
# Layer idx: 12 routing completed in time: 0.35763096809387207 seconds!
#
# Current layer index is:  13
# Layer idx: 13 routing completed in time: 0.315824031829834 seconds!
#
# Current layer index is:  14
# Layer idx: 14 routing completed in time: Layer idx:2.193450927734375e-05  136seconds!
#
#  Current layer index is:  15routing completed in time:
#  0.7774457931518555 seconds!
#
# Current layer index is:  137
# Layer idx: 15 routing completed in time: 0.42081522941589355 seconds!
#
# Current layer index is:  16
# Layer idx: 218 routing completed in time: 8.081414937973022 seconds!
#
# Current layer index is:  219
# Layer idx: 219 routing completed in time: 1.3511989116668701 seconds!
#
# Current layer index is:  220
# Layer idx: 89 routing completed in time: 14.153197050094604 seconds!
#
# Current layer index is:  90
# Layer idx: 16 routing completed in time: 4.391538858413696 seconds!
#
# Current layer index is:  17
# Layer idx: 220 routing completed in time: 4.598013877868652 seconds!
#
# Current layer index is:  221
# Layer idx: 137 routing completed in time: 8.195130825042725 seconds!
#
# Current layer index is:  138
# Layer idx: 221 routing completed in time: 1.322573184967041 seconds!
#
# Current layer index is:  222
# Layer idx: 222 routing completed in time: 2.86102294921875e-06 seconds!
#
# Current layer index is:  223
# Layer idx: 138 routing completed in time: 0.9741618633270264 seconds!
#
# Current layer index is:  139
# Layer idx: 139 routing completed in time: 0.29368114471435547 seconds!
#
# Current layer index is:  140
# Layer idx: 140 routing completed in time: 0.3439748287200928 seconds!
#
# Current layer index is:  141
# Layer idx: Layer idx:223  routing completed in time:141  1.860948085784912routing completed in time:  0.33419299125671387seconds!
#
# Current layer index is: seconds!
#
#  224Current layer index is:
#  142
# Layer idx: 142 routing completed in time: 0.427105188369751 seconds!
#
# Current layer index is:  143
# Layer idx: 90 routing completed in time: 8.896693706512451 seconds!
#
# Current layer index is:  91
# Layer idx: 91 routing completed in time: 0.33069396018981934 seconds!
#
# Current layer index is:  92
# Layer idx: 92 routing completed in time: 0.3372340202331543 seconds!
#
# Current layer index is:  93
# Layer idx: 143 routing completed in time: 4.268404006958008 seconds!
#
# Current layer index is:  144
# Layer idx: 93 routing completed in time: 2.6444239616394043 seconds!
#
# Current layer index is:  94
# Layer idx: 224 routing completed in time: 6.912330865859985 seconds!
#
# Current layer index is:  225
# Layer idx: 53 routing completed in time: 30.17204999923706 seconds!
#
# Current layer index is:  54
# Layer idx: 54 routing completed in time: 0.34776878356933594 seconds!
#
# Current layer index is:  55
# Layer idx: 55 routing completed in time: 5.245208740234375e-06 seconds!
#
# Current layer index is:  56
# Layer idx: 94 routing completed in time: 5.863984823226929 seconds!
#
# Current layer index is:  95
# Layer idx: 56 routing completed in time: 1.0253069400787354 seconds!
#
# Current layer index is:  57
# Layer idx: 57 routing completed in time: 0.42140889167785645 seconds!
#
# Current layer index is:  58
# Layer idx:Layer idx:  5895 routing completed in time:  1.9073486328125e-06routing completed in time: seconds!
#
#  Current layer index is: 1.2839951515197754  59seconds!
#
#
# Layer idx:Current layer index is:   5996
# routing completed in time:Layer idx: 1.6689300537109375e-06  seconds!
#
# 96Current layer index is:   60
# routing completed in time: 4.76837158203125e-06 seconds!
#
# Current layer index is:  97
# Layer idx: 60 routing completed in time: 0.36557984352111816 seconds!
# Layer idx:
#  97Current layer index is:   routing completed in time:61
#  Layer idx: 0.33878612518310547 61seconds!
#
# routing completed in time:Current layer index is:   5.0067901611328125e-0698
# seconds!
# Layer idx:
#  Current layer index is: 98  62routing completed in time:
#  2.1457672119140625e-06 Layer idx:seconds!
#
# 62Current layer index is:   99
# routing completed in time: 2.1457672119140625e-06 seconds!
#
# Current layer index is:  63
# Layer idx: 99 routing completed in time: 0.34528088569641113 seconds!
#
# Current layer index is:  100
# Layer idx: 63 routing completed in time: 0.35355710983276367 seconds!
#
# Current layer index is:  64
# Layer idx: 100 routing completed in time: 0.41594696044921875 seconds!
#
# Current layer index is:  101
# Layer idx: 225 routing completed in time:Layer idx:  6.92377901077270564  seconds!
# routing completed in time:
# Current layer index is:   0.7177932262420654226 seconds!
#
#
# Current layer index is:  65
# Layer idx: 101 routing completed in time: 0.7758021354675293 seconds!
#
# Current layer index is: Layer idx:  102
# 65 routing completed in time: 0.4415469169616699 seconds!
#
# Current layer index is:  66
# Layer idx: 66 routing completed in time: 0.4072098731994629 seconds!
#
# Current layer index is:  67
# Layer idx: 226 routing completed in time: 1.3538849353790283 seconds!
#
# Current layer index is:  227
# Layer idx: 277 routing completed in time: 30.637481927871704 seconds!
#
# Current layer index is:  278
# Layer idx: 67 routing completed in time: 1.1901881694793701 seconds!
#
# Current layer index is:  68
# Layer idx: 68 Layer idx: routing completed in time: 1024.0531158447265625e-06  routing completed in time:seconds!
#
#  Current layer index is:  1.784658908843994169
#  seconds!
#
# Current layer index is:  103
# Layer idx: 278 routing completed in time: 0.5369808673858643 seconds!
#
# Current layer index is:  279
# Layer idx: 227Layer idx:Layer idx:   27969  routing completed in time:routing completed in time:routing completed in time:  2.86102294921875e-060.3278219699859619  seconds!
# seconds!
#
#
# Current layer index is: 1.294482946395874Current layer index is:    70280
#
# seconds!
#
# Current layer index is:  228
# Layer idx: 280 routing completed in time: 0.4578249454498291 seconds!
#
# Current layer index is:  281
# Layer idx: 70 routing completed in time: 0.9660139083862305 seconds!
#
# Current layer index is:  71
# Layer idx: 103 routing completed in time: 1.4825327396392822 seconds!
#
# Current layer index is:  104
# Layer idx: 281 routing completed in time: 0.8210361003875732 seconds!
#
# Current layer index is:  282
# Layer idx: 282 routing completed in time: 0.3842031955718994 seconds!
#
# Current layer index is:  283
# Layer idx: 228 routing completed in time: 2.426759958267212 Layer idx: seconds!
#
# 283Current layer index is:   routing completed in time:229
# 0.5809991359710693 seconds!
#
# Current layer index is:  284
# Layer idx: 284 routing completed in time: 4.0531158447265625e-06 seconds!
#
# Current layer index is:  285
# Layer idx: 104 Layer idx:routing completed in time:  1.3917570114135742285  routing completed in time: seconds!
# 2.1457672119140625e-06
#  Current layer index is: seconds!
#
# Current layer index is: 105
# 286
# Layer idx: 286 routing completed in time: 9.5367431640625e-07 seconds!
#
# Current layer index is:  287
# Layer idx: 287 routing completed in time: Layer idx:0.347959041595459 Layer idx: 71 seconds!
# 105 routing completed in time:
#   Current layer index is: routing completed in time:2.1125118732452393   2880.4442770481109619seconds!
#
#
# Layer idx:seconds!
# Current layer index is:
#  288Current layer index is:  72
# routing completed in time:106
# 1.9073486328125e-06 seconds!
#
# Current layer index is:  289
# Layer idx: 289 routing completed in time: 4.0531158447265625e-06 seconds!
#
# Current layer index is:  290
# Layer idx: 290 routing completed in time: 0.48021697998046875 seconds!
#
# Current layer index is:  291
# Layer idx: 106 routing completed in time: 1.0099611282348633 seconds!
#
# Current layer index is:  107
# Layer idx: 72 routing completed in time: 1.6382179260253906 seconds!
#
# Current layer index is:  73
# Layer idx: 73 routing completed in time: 3.0994415283203125e-06 seconds!
#
# Current layer index is:  74
# Layer idx: 107 routing completed in time: 0.8878707885742188 seconds!
#
# Current layer index is:  108
# Layer idx: 291 routing completed in time: 2.9660751819610596 seconds!
#
# Current layer index is:  292
# Layer idx: 108 routing completed in time: 1.7613780498504639 seconds!
#
# Current layer index is:  109
# Layer idx: 292 routing completed in time: 0.7170979976654053 seconds!
#
# Current layer index is:  293
# Layer idx: 293 routing completed in time: 0.3503239154815674 seconds!
#
# Current layer index is:  294
# Layer idx: 294 routing completed in time: 0.3318028450012207 seconds!
#
# Current layer index is:  295
# Layer idx: 295 routing completed in time: 5.9604644775390625e-06 seconds!
#
# Current layer index is:  296
# Layer idx: 296 routing completed in time: 0.32072973251342773 seconds!
#
# Current layer index is:  297
# Layer idx: 109 routing completed in time: 1.9445841312408447 seconds!
#
# Current layer index is:  110
# Layer idx: 74 routing completed in time: 4.565211296081543 seconds!
#
# Current layer index is:  75
# Layer idx: 229 routing completed in time: 9.169191837310791 seconds!
#
# Current layer index is:  230
# Layer idx: 297 routing completed in time: 3.1597869396209717 seconds!
#
# Current layer index is:  298
# Layer idx: 17 routing completed in time: 38.05851411819458 seconds!
#
# Current layer index is:  18
# Layer idx: 18 routing completed in time: 0.331373929977417 seconds!
#
# Current layer index is:  19
# Layer idx: 19 routing completed in time: 3.0994415283203125e-06 seconds!
#
# Current layer index is:  20
# Layer idx: 20 routing completed in time: 0.3608570098876953 seconds!
#
# Current layer index is:  21
# Layer idx: 75 routing completed in time: 7.3784239292144775 seconds!
#
# Current layer index is:  76
# Layer idx: 76 routing completed in time: 5.245208740234375e-06 seconds!
#
# Current layer index is:  77
# Layer idx: 77 routing completed in time: 1.9073486328125e-06 seconds!
#
# Current layer index is:  78
# Layer idx: 78 routing completed in time: 0.5560441017150879 seconds!
#
# Current layer index is:  79
# Layer idx: 230 routing completed in time: 6.184108018875122 seconds!
#
# Current layer index is:  231
# Layer idx: 79 routing completed in time: 0.28899574279785156 seconds!
#
# Current layer index is:  80
# Layer idx: 80 routing completed in time: 3.0994415283203125e-06 seconds!
#
# Current layer index is:  81
# Layer idx: 81 routing completed in time: 0.34816789627075195 seconds!
#
# Current layer index is:  82
# Layer idx: 298 routing completed in time: 8.142488241195679 seconds!
#
# Current layer index is:  299
# Layer idx: Layer idx:82  routing completed in time:299  2.0665578842163086routing completed in time: seconds!
#
# 0.33027219772338867Current layer index is:  seconds!
#  83
#
# Current layer index is:  300
# Layer idx: 300 routing completed in time: 6.198883056640625e-06 seconds!
#
# Layer idx: 21 routing completed in time: 4.2707719802856445 seconds!
#
# Current layer index is:  22
# Layer idx: 22 routing completed in time: 4.76837158203125e-06 seconds!
#
# Current layer index is:  23
# Layer idx: 23 routing completed in time: 2.86102294921875e-06 seconds!
#
# Current layer index is:  24
# Layer idx: 24 routing completed in time: 0.5158839225769043 seconds!
#
# Current layer index is:  25
# Layer idx: 25 routing completed in time: 1.6689300537109375e-06 seconds!
#
# Current layer index is:  26
# Layer idx: 26 routing completed in time: 5.7220458984375e-06 seconds!
#
# Current layer index is:  27
# Layer idx: 27 routing completed in time: 0.31097984313964844 seconds!
#
# Current layer index is:  28
# Layer idx: 28 routing completed in time: 0.27686214447021484 seconds!
#
# Current layer index is:  29
# Layer idx: 29 routing completed in time: 0.30835413932800293 seconds!
#
# Current layer index is:  30
# Layer idx: 30 routing completed in time: 0.28957629203796387 seconds!
#
# Current layer index is:  31
# Layer idx: 31 routing completed in time: 0.2788729667663574 seconds!
#
# Current layer index is:  32
# Layer idx: 32 routing completed in time: 3.0994415283203125e-06 seconds!
#
# Current layer index is:  33
# Layer idx: 33 routing completed in time: 0.3135380744934082 seconds!
#
# Current layer index is:  34
# Layer idx: 34 routing completed in time: 0.280426025390625 seconds!
#
# Current layer index is:  35
# Layer idx: 231 routing completed in time: 5.960179090499878 seconds!
#
# Current layer index is:  232
# Layer idx: 232 routing completed in time: 2.1457672119140625e-06 seconds!
#
# Current layer index is:  233
# Layer idx: 35 routing completed in time: 0.7629308700561523 seconds!
#
# Current layer index is:  36
# Layer idx: 233 routing completed in time: 1.0374360084533691 seconds!
#
# Current layer index is:  234
# Layer idx: 36 routing completed in time: 0.3223259449005127 seconds!
#
# Current layer index is:  37
# Layer idx: 37 routing completed in time: 4.0531158447265625e-06 seconds!
#
# Current layer index is:  38
# Layer idx: 38 routing completed in time: 0.3701760768890381 seconds!
#
# Current layer index is:  39
# Layer idx: 39 routing completed in time: 0.3914639949798584 seconds!
#
# Current layer index is:  40
# Layer idx: 40 routing completed in time: 5.0067901611328125e-06 seconds!
#
# Current layer index is:  41
# Layer idx: 41 routing completed in time: 1.9073486328125e-06 seconds!
#
# Current layer index is:  42
# Layer idx: 234 routing completed in time: 1.2391390800476074 seconds!
#
# Current layer index is:  235
# Layer idx: 42 routing completed in time: 0.31852006912231445 seconds!
#
# Layer idx: 83 routing completed in time: 6.368726015090942 seconds!
#
# Current layer index is:  84
# Layer idx: 181 routing completed in time: 58.77448797225952 seconds!
#
# Current layer index is:  182
# Layer idx: 235 routing completed in time: 1.918412208557129 seconds!
#
# Current layer index is:  236
# Layer idx: 182 routing completed in time: 0.8261520862579346 seconds!
#
# Current layer index is:  183
# Layer idx: 236 routing completed in time: 0.6677591800689697 seconds!
#
# Current layer index is:  237
# Layer idx: 237 routing completed in time: 1.9073486328125e-06 seconds!
#
# Current layer index is:  238
# Layer idx: 84 routing completed in time: 2.120727062225342 seconds!
#
# Current layer index is:  85
# Layer idx: 238 routing completed in time: 0.4275383949279785 seconds!
#
# Current layer index is:  239
# Layer idx: 85 routing completed in time: 0.34218287467956543 seconds!
#
# Layer idx: 239 routing completed in time: 0.7108798027038574 seconds!
#
# Current layer index is:  240
# Layer idx: 183 routing completed in time: 1.5923171043395996 seconds!
#
# Current layer index is:  184
# Layer idx: 240 routing completed in time: 0.981558084487915 seconds!
#
# Current layer index is:  241
# Layer idx: 144 routing completed in time: 43.53024697303772 seconds!
#
# Current layer index is:  145
# Layer idx: 184 routing completed in time: 1.2562870979309082 seconds!
#
# Current layer index is:  185
# Layer idx: 241 routing completed in time: 0.712925910949707 seconds!
#
# Current layer index is:  242
# Layer idx: 242 routing completed in time: 2.1457672119140625e-06 seconds!
#
# Current layer index is:  243
# Layer idx: 243 routing completed in time: 3.0994415283203125e-06 seconds!
#
# Current layer index is:  244
# Layer idx: 244 routing completed in time: 1.9073486328125e-06 seconds!
#
# Current layer index is:  245
# Layer idx: 245 routing completed in time: 0.3395729064941406 seconds!
#
# Layer idx:Current layer index is:   185246
# routing completed in time:Layer idx:  0.5138161182403564246  seconds!
# routing completed in time:
#  Current layer index is: 9.5367431640625e-07  186seconds!
#
#
# Current layer index is:  247
# Layer idx: 247 routing completed in time: 1.9073486328125e-06 seconds!
#
# Current layer index is:  248
# Layer idx: 186 routing completed in time: 0.2922177314758301 seconds!
#
# Current layer index is:  187
# Layer idx: 248 routing completed in time: 0.3110220432281494 seconds!
#
# Current layer index is:  249
# Layer idx: 187 routing completed in time: 0.35212230682373047 seconds!
#
# Current layer index is:  188
# Layer idx: 249 routing completed in time: 0.596560001373291 seconds!
#
# Current layer index is:  250
# Layer idx: 250 routing completed in time: 0.2724192142486572 seconds!
#
# Current layer index is:  251
# Layer idx: 188 routing completed in time: 0.7025089263916016 seconds!
#
# Current layer index is:  189
# Layer idx: 251 routing completed in time: 0.3088080883026123 seconds!
#
# Current layer index is:  252
# Layer idx: 189 routing completed in time: 0.34922218322753906 seconds!
#
# Current layer index is:  190
# Layer idx: 190 routing completed in time: 2.1457672119140625e-06 seconds!
#
# Current layer index is:  191
# Layer idx: 252 routing completed in time: 0.2824258804321289 seconds!
#
# Current layer index is:  253
# Layer idx: 253 routing completed in time: 1.9073486328125e-06 seconds!
#
# Current layer index is:  254
# Layer idx: 191 routing completed in time: 0.3173859119415283 seconds!
#
# Current layer index is:  192
# Layer idx: 254 routing completed in time: 0.32590222358703613 seconds!
#
# Current layer index is:  255
# Layer idx: 192 routing completed in time: 0.5885200500488281 seconds!
#
# Current layer index is:  193
# Layer idx: 255 routing completed in time: 0.6211225986480713 seconds!
#
# Current layer index is:  256
# Layer idx: 193 routing completed in time: 0.47977185249328613 seconds!
#
# Current layer index is:  194
# Layer idx: 194 routing completed in time: 0.29013514518737793 seconds!
#
# Current layer index is:  195
# Layer idx: 110 routing completed in time: 27.259128093719482Layer idx:  seconds!
# 195
#  Current layer index is: routing completed in time:  1110.3040781021118164
#  seconds!
#
# Current layer index is:  196
# Layer idx: 196 routing completed in time: 0.37005114555358887 seconds!
#
# Current layer index is:  197
# Layer idx: 256 routing completed in time: 1.680722951889038 seconds!
#
# Current layer index is:  257
# Layer idx: 257 routing completed in time: 0.6670348644256592 seconds!
#
# Layer idx: 111 routing completed in time: 1.2155320644378662 seconds!
#
# Current layer index is:  112
# Layer idx: 197 routing completed in time: 1.1364729404449463 seconds!
#
# Current layer index is:  198
# Layer idx: 112 routing completed in time: 0.454664945602417 seconds!
#
# Current layer index is:  113
# Layer idx: 113 routing completed in time: 0.26963305473327637 seconds!
#
# Current layer index is:  114
# Layer idx: 114 routing completed in time: 0.37667012214660645 seconds!
#
# Current layer index is:  115
# Layer idx: 198 routing completed in time: 0.8757040500640869 seconds!
#
# Current layer index is:  199
# Layer idx: 115 routing completed in time: 0.33223700523376465 seconds!
#
# Current layer index is:  116
# Layer idx: 116 routing completed in time: 0.3730340003967285 seconds!
#
# Current layer index is:  117
# Layer idx: 117 routing completed in time: 1.9073486328125e-06 seconds!
#
# Current layer index is:  118
# Layer idx: 145 routing completed in time: 8.258161067962646 seconds!
#
# Current layer index is:  146
# Layer idx: 118 routing completed in time: 0.8450510501861572 seconds!
#
# Current layer index is:  119
# Layer idx: 146 routing completed in time: 0.44290614128112793 seconds!
#
# Current layer index is:  147
# Layer idx: 199 routing completed in time: 1.9783210754394531 seconds!
#
# Current layer index is:  200
# Layer idx: 119 routing completed in time: 0.5943348407745361 seconds!
#
# Current layer index is:  120
# Layer idx: 200 routing completed in time: 0.8500370979309082 seconds!
#
# Current layer index is:  201
# Layer idx: 201 routing completed in time: 1.9073486328125e-06 seconds!
#
# Current layer index is:  202
# Layer idx: 120 routing completed in time: 1.4116849899291992 seconds!
#
# Current layer index is:  121
# Layer idx: 121 routing completed in time: 0.2756969928741455 seconds!
#
# Current layer index is:  122
# Layer idx: 122 routing completed in time: 0.2808866500854492 seconds!
#
# Current layer index is:  123
# Layer idx: 123 routing completed in time: 0.3090839385986328 seconds!
#
# Current layer index is:  124
# Layer idx: 202 routing completed in time: 2.583960771560669 seconds!
#
# Current layer index is:  203
# Layer idx: 124 routing completed in time: 1.4237980842590332 seconds!
#
# Current layer index is:  125
# Layer idx: 125 routing completed in time: 0.751673698425293 seconds!
#
# Current layer index is:  126
# Layer idx: 203 routing completed in time: 1.4873480796813965 seconds!
#
# Current layer index is:  204
# Layer idx: 204 routing completed in time: 0.7099640369415283 seconds!
#
# Current layer index is:  205
# Layer idx: 147 routing completed in time: 6.146412134170532 seconds!
#
# Current layer index is:  148
# Layer idx: 205 routing completed in time: 0.8865909576416016 seconds!
#
# Current layer index is:  206
# Layer idx: 126 routing completed in time: 2.090641736984253 seconds!
#
# Current layer index is:  127
# Layer idx: 206 routing completed in time: 0.2705199718475342 seconds!
#
# Current layer index is:  207
# Layer idx: 207 routing completed in time: 0.2864868640899658 seconds!
#
# Current layer index is:  208
# Layer idx: 127 routing completed in time: 0.6538550853729248 seconds!
#
# Current layer index is:  128
# Layer idx: 128 routing completed in time: 1.9073486328125e-06 seconds!
#
# Layer idx: 208 routing completed in time: 0.49117493629455566 seconds!
#
# Current layer index is:  209
# Layer idx: 209 routing completed in time: 1.773428201675415 seconds!
#
# Current layer index is:  210
# Layer idx: 210 routing completed in time: 1.7484488487243652 seconds!
#
# Current layer index is:  211
# Layer idx: 211 routing completed in time: 0.8418052196502686 seconds!
#
# Current layer index is:  212
# Layer idx: 212 routing completed in time: 0.25838208198547363 seconds!
#
# Current layer index is:  213
# Layer idx: 213 routing completed in time: 0.26117777824401855 seconds!
#
# Current layer index is:  214
# Layer idx: 214 routing completed in time: 0.25600481033325195 seconds!
#
# Layer idx: 148 routing completed in time: 15.877077102661133 seconds!
#
# Current layer index is:  149
# Layer idx: 149 routing completed in time: 1.9073486328125e-06 seconds!
#
# Current layer index is:  150
# Layer idx: 150 routing completed in time: 0.26428914070129395 seconds!
#
# Current layer index is:  151
# Layer idx: 151 routing completed in time: 6.48825478553772 seconds!
#
# Current layer index is:  152
# Layer idx: 152 routing completed in time: 30.051790714263916 seconds!
#
# Current layer index is:  153
# Layer idx: 153 routing completed in time: 0.24572491645812988 seconds!
#
# Current layer index is:  154
# Layer idx: 154 routing completed in time: 0.2738018035888672 seconds!
#
# Current layer index is:  155
# Layer idx: 155 routing completed in time: 9.73769998550415 seconds!
#
# Current layer index is:  156
# Layer idx: 156 routing completed in time: 13.277450799942017 seconds!
#
# Current layer index is:  157
# Layer idx: 157 routing completed in time: 11.009366989135742 seconds!
#
# Current layer index is:  158
# Layer idx: 158 routing completed in time: 12.167734146118164 seconds!
#
# Current layer index is:  159
# Layer idx: 159 routing completed in time: 0.29401183128356934 seconds!
#
# Current layer index is:  160
# Layer idx: 160 routing completed in time: 0.3428690433502197 seconds!
#
# Current layer index is:  161
# Layer idx: 161 routing completed in time: 8.386983871459961 seconds!
#
# Current layer index is:  162
# Layer idx: 162 routing completed in time: 68.43698382377625 seconds!
#
# Current layer index is:  163
# Layer idx: 163 routing completed in time: 14.75991415977478 seconds!
#
# Current layer index is:  164
# Layer idx: 164 routing completed in time: 0.3195078372955322 seconds!
#
# Current layer index is:  165
# Layer idx: 165 routing completed in time: 0.29779696464538574 seconds!
#
# Current layer index is:  166
# Layer idx: 166 routing completed in time: 15.53219985961914 seconds!
#
# Current layer index is:  167
# Layer idx: 167 routing completed in time: 11.387288808822632 seconds!
#
# Current layer index is:  168
# Layer idx: 168 routing completed in time: 5.330115795135498 seconds!
#
# Current layer index is:  169
# Layer idx: 169 routing completed in time: 2.1457672119140625e-06 seconds!
#
# Current layer index is:  170
# Layer idx: 170 routing completed in time: 0.3094348907470703 seconds!
#
# Current layer index is:  171
# Layer idx: 171 routing completed in time: 1.9073486328125e-06 seconds!
